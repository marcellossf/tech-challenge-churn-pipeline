# %% [markdown]
# # Experimentos com MLP
#
# Use este notebook para explorar hiperparâmetros, revisar curvas de loss e consolidar a comparação final.

# %%
from tech_challenge.models.train_mlp import train_mlp
from tech_challenge.config import Settings

result = train_mlp(Settings())
result['metrics']
